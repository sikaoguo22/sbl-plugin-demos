# %% [markdown]
# ### VMD plugin
# The plugin is available in VMD under Extensions → SBL.

# %% [markdown]
# ![Open sbl_spectraldom VMD plugin](../figs/spectraldom_open_plugin.png)

# %% [markdown]
# #### Prepare the work directory and molecular structure (pdb file)
# ```bash
# mkdir -p ~/demo/spectraldom/data
# cd ~/demo/spectraldom/data
# sbl-pdb-fetch.py -f 4zit -c
# sbl-pdb-fetch.py -f 1ake -c
# sbl-pdb-fetch.py -f 4ake -c
# ```

# %% [markdown]
# ![Open sbl_spectraldom_gui_output1 VMD plugin](../figs/spectraldom_gui_output1.png)

# %% [markdown]
# ### PyMOL plugin
# Note: The PyMOL is required to built with PyQt6 support for the SBL PyMOL plugins to work correctly. PyMOL with PyQt5 is not supported.

# %% [markdown]
# Run `sbl_help` in the PyMOL command line to list all available SBL plugin commands, then run `sbl_spectraldom` to launch this plugin.
#
# The usage of this plugin is the same as in VMD.

# %% [markdown]
# ![Open sbl_spectraldom_gui_output PyMOL plugin](../figs/spectraldom_gui_output_pymol.png)

# %% [markdown]
# ### Web plugin

# %% [markdown]
# ![Open sbl_spectraldom_gui_output Web plugin](../figs/spectraldom_gui_output_web.png)
